# %% [markdown]
# # Dataframes Creation
#
# This notebook does the following:
# - Reads all the dvrk_pedals.bag, and dvrk_kinematic.bag files.
# - Preprocess them (plese refer to our paper for more details).
# - Merges them in a single Dataframe and do a small analysis of it.
#
# ## Files preparation
# To use this notebook please create a folder called bag_folder and copy inside of it each of the dvrk_pedals.bag, and dvrk_kinematic.bag. It will then be necessary to rename them. Do it as in following example:
#
# - Original folder: G_2.
# - Original .bag files names: dvrk_pedals.bag, dvrk_kinematics.bag.
# - Renamed .bag files: dvrk_pedals_G2.bag, dvrk_kinematics_G2.bag.
# - Then rename and copy inside the bag_folder the rest of the .bag files for all the procedures.
#
# Finally create another folder called df_surgeons.

# %%
import pandas as pd
import bagpy
from bagpy import bagreader
import numpy as np
import os

# %%
def sync_df(data,df1,df2):
    
    true_indices = df1.index[df1[data] == True]
    df2[data] = 0
    
    true_time=[]
    true_data_index=[]
    eps=0.006

    for i in true_indices:
        time=df1['Time'][i]
        true_time.append(time)
        true_data_index.append(df2.index[abs(df2['Time']-time) < eps])
    
    idx=[]
    
    for i in true_data_index: 
        try:   
                df2.at[i[0],data]=1
                idx.append(i[0])
        except:
                pass

    df2.loc[idx, [data]]=1
    return df2

# %%
def processing(bag_kinematic,bag_pedals,df_name):

    print("processing file: ", bag_kinematic)
    b = bagreader(bag_kinematic)
    print(b.topic_table)
    
    csvfiles = []
    
    for t in b.topics:
        data = b.message_by_topic(t)
        csvfiles.append(data)
        
    print(csvfiles[0])
    
    #DATA LOADING
    data = pd.read_csv(csvfiles[12])
    data_PSM2 = pd.read_csv(csvfiles[16])
    data_ECM=pd.read_csv(csvfiles[1])
    data_MTML=pd.read_csv(csvfiles[5])
    data_MTMR=pd.read_csv(csvfiles[9])

    
    print("renaming columns")
    #Renaming some columns for more clarity
    print("psm1")
    data.rename(columns={"transform.translation.x": "PSM1_transform.translation.x"}, inplace=True)
    data.rename(columns={"transform.translation.y": "PSM1_transform.translation.y"}, inplace=True)
    data.rename(columns={"transform.translation.z": "PSM1_transform.translation.z"}, inplace=True)
    data.rename(columns={"transform.rotation.x": "PSM1_transform.rotation.x"}, inplace=True)
    data.rename(columns={"transform.rotation.y": "PSM1_transform.rotation.y"}, inplace=True)
    data.rename(columns={"transform.rotation.z": "PSM1_transform.rotation.z"}, inplace=True)
    data.rename(columns={"transform.rotation.w": "PSM1_transform.rotation.w"}, inplace=True)
    
    data=data.drop(columns=['header.seq','header.stamp.secs','header.stamp.nsecs','header.frame_id','child_frame_id'])

    

    
    print("psm2")
    data_PSM2.rename(columns={"transform.translation.x": "PSM2_transform.translation.x"}, inplace=True)
    data_PSM2.rename(columns={"transform.translation.y": "PSM2_transform.translation.y"}, inplace=True)
    data_PSM2.rename(columns={"transform.translation.z": "PSM2_transform.translation.z"}, inplace=True)
    data_PSM2.rename(columns={"transform.rotation.x": "PSM2_transform.rotation.x"}, inplace=True)
    data_PSM2.rename(columns={"transform.rotation.y": "PSM2_transform.rotation.y"}, inplace=True)
    data_PSM2.rename(columns={"transform.rotation.z": "PSM2_transform.rotation.z"}, inplace=True)
    data_PSM2.rename(columns={"transform.rotation.w": "PSM2_transform.rotation.w"}, inplace=True)
    
    data_PSM2=data_PSM2.drop(columns=['Time','header.seq','header.stamp.secs','header.stamp.nsecs','header.frame_id','child_frame_id'])

    print("mtml")
    data_MTML.rename(columns={"transform.translation.x": "MTML_transform.translation.x"}, inplace=True)
    data_MTML.rename(columns={"transform.translation.y": "MTML_transform.translation.y"}, inplace=True)
    data_MTML.rename(columns={"transform.translation.z": "MTML_transform.translation.z"}, inplace=True)
    data_MTML.rename(columns={"transform.rotation.x": "MTML_transform.rotation.x"}, inplace=True)
    data_MTML.rename(columns={"transform.rotation.y": "MTML_transform.rotation.y"}, inplace=True)
    data_MTML.rename(columns={"transform.rotation.z": "MTML_transform.rotation.z"}, inplace=True)
    data_MTML.rename(columns={"transform.rotation.w": "MTML_transform.rotation.w"}, inplace=True)
    
    data_MTML=data_MTML.drop(columns=['Time','header.seq','header.stamp.secs','header.stamp.nsecs','header.frame_id','child_frame_id'])

    print("mtmr")
    data_MTMR.rename(columns={"transform.translation.x": "MTMR_transform.translation.x"}, inplace=True)
    data_MTMR.rename(columns={"transform.translation.y": "MTMR_transform.translation.y"}, inplace=True)
    data_MTMR.rename(columns={"transform.translation.z": "MTMR_transform.translation.z"}, inplace=True)
    data_MTMR.rename(columns={"transform.rotation.x": "MTMR_transform.rotation.x"}, inplace=True)
    data_MTMR.rename(columns={"transform.rotation.y": "MTMR_transform.rotation.y"}, inplace=True)
    data_MTMR.rename(columns={"transform.rotation.z": "MTMR_transform.rotation.z"}, inplace=True)
    data_MTMR.rename(columns={"transform.rotation.w": "MTMR_transform.rotation.w"}, inplace=True)
    
    data_MTMR=data_MTMR.drop(columns=['Time','header.seq','header.stamp.secs','header.stamp.nsecs','header.frame_id','child_frame_id'])

    print("ecm")
    data_ECM.rename(columns={"transform.translation.x": "ECM_transform.translation.x"}, inplace=True)
    data_ECM.rename(columns={"transform.translation.y": "ECM_transform.translation.y"}, inplace=True)
    data_ECM.rename(columns={"transform.translation.z": "ECM_transform.translation.z"}, inplace=True)
    data_ECM.rename(columns={"transform.rotation.x": "ECM_transform.rotation.x"}, inplace=True)
    data_ECM.rename(columns={"transform.rotation.y": "ECM_transform.rotation.y"}, inplace=True)
    data_ECM.rename(columns={"transform.rotation.z": "ECM_transform.rotation.z"}, inplace=True)
    data_ECM.rename(columns={"transform.rotation.w": "ECM_transform.rotation.w"}, inplace=True)
    
    data_ECM=data_ECM.drop(columns=['Time','header.seq','header.stamp.secs','header.stamp.nsecs','header.frame_id','child_frame_id'])
    

    frames = [data, data_PSM2,data_ECM,data_MTML,data_MTMR]
    data_kinematic=pd.concat(frames,axis=1)
    

    
    # exctracting and sync. the pedals .bag folder
    print("processing pedals: ",bag_pedals)
    try:
        bag_pedals = bagreader(bag_pedals)
        
        print(bag_pedals.topic_table)
        
        topic1 = '/pedals/camera'
        topic2 = '/pedals/clutch'
        topic4_1 = '/pedals/read/monopolar'
        topic4_2 = '/pedals/monopolar'
    
        csvfiles = []
    
        data_camera = bag_pedals.message_by_topic(topic1)
        data_pedal = bag_pedals.message_by_topic(topic2)
        data_monopolar = bag_pedals.message_by_topic(topic4_1)
    
        if data_monopolar is None:
            # If data_monopolar is not found, try the alternative topic
            data_monopolar = bag_pedals.message_by_topic(topic4_2)
        
        dataframe_camera = pd.read_csv(data_camera)
        dataframe_pedal= pd.read_csv(data_pedal)
        dataframe_monopolar=pd.read_csv(data_monopolar)
        #dataframe_bipolar=pd.read_csv(data_bipolar)
        
        dataframe_camera.rename(columns={"data": "data_camera"}, inplace=True)
        dataframe_pedal.rename(columns={"data": "data_clutch"}, inplace=True)
        dataframe_pedal=dataframe_pedal.drop(columns=['Time','header.seq','header.stamp.secs','header.stamp.nsecs','header.frame_id'])
        dataframe_monopolar.rename(columns={"data": "data_monopolar"}, inplace=True)
        dataframe_monopolar=dataframe_monopolar.drop(columns=['Time','header.seq','header.stamp.secs','header.stamp.nsecs','header.frame_id'])
        
        
        frames = [dataframe_camera, dataframe_pedal,dataframe_monopolar]#,dataframe_bipolar]
        pedals_dataframe=pd.concat(frames,axis=1)
        
        data=sync_df('data_clutch',pedals_dataframe,data_kinematic)
        data=sync_df('data_camera',pedals_dataframe,data_kinematic)
        data=sync_df('data_monopolar',pedals_dataframe,data_kinematic)
        
        first_value = data['Time'].iloc[0]
        data['Time'] = data['Time'] - first_value 
    except: 
        pass
    
    # VISUALIZING ALL COLUMNS AND SAVING THE FILE TO CSV
    
    for col in data.columns:
        print(col)
    print("dataset created with the name: ", df_name)
    data.to_csv(df_name, index=False)

# %%
def extract_last_word_after_underscore(file_name):
    # Split the filename by underscore (_) and get the last part
    parts = file_name.split('_')
    return parts[-1] if len(parts) >= 2 else None

def list_words_after_last_underscore_in_folder(folder_path):
    # Check if the path is a directory
    if os.path.isdir(folder_path):
        # Get a list of all files in the directory
        files = os.listdir(folder_path)

        # Extract the word after the last underscore from each filename
        words_after_last_underscore = [extract_last_word_after_underscore(file) for file in files]

        # Filter out None values, duplicates, and those not ending with ".bag"
        words_after_last_underscore = set(word for word in words_after_last_underscore if word and word.endswith(".bag"))
        return list(words_after_last_underscore)
    else:
        print(f"{folder_path} is not a valid directory.")

# Replace 'your_folder_path' with the path to the folder you want to list
folder_path = ''
words_list = list_words_after_last_underscore_in_folder(folder_path)

if words_list:
    print("List of Valid names found:")
    for word in words_list:
        print(word)
else:
    print("No valid words found after the last underscore ending with '.bag' in the specified folder.")
# Out:
# List of unique words after the last underscore ending with '.bag' in the filenames:
# AD2.bag
# VL2.bag
# MDP1.bag
# MDP3.bag
# LA2.bag
# GP2.bag
# LA3.bag
# GP1.bag
# AM3.bag
# AM2.bag
# VL3.bag
# AD1.bag
# FT3.bag
# GP3.bag
# MDP2.bag
# VL1.bag
# LA1.bag
# AD3.bag
# FT2.bag
# FT1.bag
# AM1.bag

# %%
def generate_strings(element):

    if element.endswith(".bag"):
        
        # Generate the three strings, specify the path to the bag folder for string1 and 2, and for string3 specify the folder where you
        # want to save the dataframes
        
        string1 = f".../bag_folder/dvrk_pedals_{element}"
        string2 = f".../bag_folder/dvrk_kinematics_{element}"
        string3 = f".../df_{element}"
        string3=string3.replace(".bag", ".csv")

        return string1, string2, string3
        
    else:
        print(f"Invalid element: {element}")

words_list = list_words_after_last_underscore_in_folder(folder_path)

if words_list:
    for word in words_list:
        strings = generate_strings(word)
        processing(strings[1],strings[0],strings[2])
        print(strings[0])
else:
    print("No valid words found after the last underscore ending with '.bag' in the specified folder.")
# Out:
# processing file:  /home/phd-leonardo-sitl/Desktop/PhdLeo/AutoClutch/bag_folder/dvrk_kinematics_AD2.bag
# [INFO]  Data folder /home/phd-leonardo-sitl/Desktop/PhdLeo/AutoClutch/bag_folder/dvrk_kinematics_AD2 already exists. Not creating.
#                             Topics                           Types  \
# 0    /ECM/custom/local/setpoint_cp  geometry_msgs/TransformStamped
# 1          /ECM/custom/setpoint_cp  geometry_msgs/TransformStamped
# 2                 /ECM/measured_js          sensor_msgs/JointState
# 3        /MTML/gripper/measured_js          sensor_msgs/JointState
# 4          /MTML/local/measured_cp  geometry_msgs/TransformStamped
# 5                /MTML/measured_cp  geometry_msgs/TransformStamped
# 6                /MTML/measured_js          sensor_msgs/JointState
# 7        /MTMR/gripper/measured_js          sensor_msgs/JointState
# 8          /MTMR/local/measured_cp  geometry_msgs/TransformStamped
# 9                /MTMR/measured_cp  geometry_msgs/TransformStamped
# 10               /MTMR/measured_js          sensor_msgs/JointState
# 11  /PSM1/custom/local/setpoint_cp  geometry_msgs/TransformStamped
# 12        /PSM1/custom/setpoint_cp  geometry_msgs/TransformStamped
# 13           /PSM1/jaw/measured_js          sensor_msgs/JointState
# 14               /PSM1/measured_js          sensor_msgs/JointState
# 15  /PSM2/custom/local/setpoint_cp  geometry_msgs/TransformStamped
# 16        /PSM2/custom/setpoint_cp  geometry_msgs/TransformStamped
# 17           /PSM2/jaw/measured_js          sensor_msgs/JointState
# 18               /PSM2/measured_js          sensor_msgs/JointState
#
#     Message Count   Frequency
# 0           87482   99.516075
# 1           87482   99.516075
# 2           87482  101.057826
# 3           87482  101.060261
# 4           87482  101.145558
# 5           87482  101.145558
# 6           87482  101.060261
# 7           87482  101.062696
# 8           87482  101.140680
# 9           87482  101.140680
# 10          87482  101.060261
# 11          87482   99.516075
# 12          87482   99.516075
# 13          87482  101.138241
# 14          87482  101.072437
# 15          87482   99.516075
# 16          87482   99.516075
# 17          87482  101.128487
# 18          87482  101.077309
# /home/phd-leonardo-sitl/Desktop/PhdLeo/AutoClutch/bag_folder/dvrk_kinematics_AD2/ECM-custom-local-setpoint_cp.csv
# renaming columns
# psm1
# psm2
# mtml
# mtmr
# ecm
# processing pedals:  /home/phd-leonardo-sitl/Desktop/PhdLeo/AutoClutch/bag_folder/dvrk_pedals_AD2.bag
# [INFO]  Data folder /home/phd-leonardo-sitl/Desktop/PhdLeo/AutoClutch/bag_folder/dvrk_pedals_AD2 already exists. Not creating.
#                    Topics                  Types  Message Count   Frequency
# 0          /pedals/camera  sitl_dvrk/BoolStamped          80368  100.004864
# 1          /pedals/clutch  sitl_dvrk/BoolStamped          80368  100.004864
# 2  /pedals/read/monopolar  sitl_dvrk/BoolStamped          80368  111.110334
# Time
# PSM1_transform.translation.x
# PSM1_transform.translation.y
# PSM1_transform.translation.z
# PSM1_transform.rotation.x
# PSM1_transform.rotation.y
# PSM1_transform.rotation.z
# PSM1_transform.rotation.w
# PSM2_transform.translation.x
# PSM2_transform.translation.y
# PSM2_transform.translation.z
# PSM2_transform.rotation.x
# PSM2_transform.rotation.y
# PSM2_transform.rotation.z
# PSM2_transform.rotation.w
# ECM_transform.translation.x
# ECM_transform.translation.y
# ECM_transform.translation.z
# ECM_transform.rotation.x
# ECM_transform.rotation.y
# ECM_transform.rotation.z
# ECM_transform.rotation.w
# MTML_transform.translation.x
# MTML_transform.translation.y
# MTML_transform.translation.z
# MTML_transform.rotation.x
# MTML_transform.rotation.y
# MTML_transform.rotation.z
# MTML_transform.rotation.w
# MTMR_transform.translation.x
# MTMR_transform.translation.y
# MTMR_transform.translation.z
# MTMR_transform.rotation.x
# MTMR_transform.rotation.y
# MTMR_transform.rotation.z
# MTMR_transform.rotation.w
# data_clutch
# data_camera
# data_monopolar
# dataset created with the name:  /home/phd-leonardo-sitl/Desktop/PhdLeo/AutoClutch/df_surgeons/df_AD2.csv
# /home/phd-leonardo-sitl/Desktop/PhdLeo/AutoClutch/bag_folder/dvrk_pedals_AD2.bag
# processing file:  /home/phd-leonardo-sitl/Desktop/PhdLeo/AutoClutch/bag_folder/dvrk_kinematics_VL2.bag
# [INFO]  Data folder /home/phd-leonardo-sitl/Desktop/PhdLeo/AutoClutch/bag_folder/dvrk_kinematics_VL2 already exists. Not creating.
#                             Topics                           Types  \
# 0    /ECM/custom/local/setpoint_cp  geometry_msgs/TransformStamped
# 1          /ECM/custom/setpoint_cp  geometry_msgs/TransformStamped
# 2                 /ECM/measured_js          sensor_msgs/JointState
# 3        /MTML/gripper/measured_js          sensor_msgs/JointState
# 4          /MTML/local/measured_cp  geometry_msgs/TransformStamped
# 5                /MTML/measured_cp  geometry_msgs/TransformStamped
# 6                /MTML/measured_js          sensor_msgs/JointState
# 7        /MTMR/gripper/measured_js          sensor_msgs/JointState
# 8          /MTMR/local/measured_cp  geometry_msgs/TransformStamped
# 9                /MTMR/measured_cp  geometry_msgs/TransformStamped
# 10               /MTMR/measured_js          sensor_msgs/JointState
# 11  /PSM1/custom/local/setpoint_cp  geometry_msgs/TransformStamped
# 12        /PSM1/custom/setpoint_cp  geometry_msgs/TransformStamped
# 13           /PSM1/jaw/measured_js          sensor_msgs/JointState
# 14               /PSM1/measured_js          sensor_msgs/JointState
# 15  /PSM2/custom/local/setpoint_cp  geometry_msgs/TransformStamped
# 16        /PSM2/custom/setpoint_cp  geometry_msgs/TransformStamped
# 17           /PSM2/jaw/measured_js          sensor_msgs/JointState
# 18               /PSM2/measured_js          sensor_msgs/JointState
#
#     Message Count   Frequency
# 0           95259   99.466515
# 1           95259   99.464156
# 2           95259  100.747118
# 3           95259  100.735019
# 4           95259  100.698742
# 5           95259  100.698742
# 6           95259  100.735019
# 7           95259  100.732600
# 8           95259  100.693907
# 9           95259  100.693907
# 10          95259  100.730181
# 11          95259   99.464156
# 12          95259   99.464156
# 13          95259  100.696324
# 14          95259  100.715668
# 15          95259   99.464156
# 16          95259   99.464156
# 17          95259  100.689072
# 18          95259  100.713250
# /home/phd-leonardo-sitl/Desktop/PhdLeo/AutoClutch/bag_folder/dvrk_kinematics_VL2/ECM-custom-local-setpoint_cp.csv
# renaming columns
# psm1
# psm2
# mtml
# mtmr
# ecm
# processing pedals:  /home/phd-leonardo-sitl/Desktop/PhdLeo/AutoClutch/bag_folder/dvrk_pedals_VL2.bag
# Time
# PSM1_transform.translation.x
# PSM1_transform.translation.y
# PSM1_transform.translation.z
# PSM1_transform.rotation.x
# PSM1_transform.rotation.y
# PSM1_transform.rotation.z
# PSM1_transform.rotation.w
# dataset created with the name:  /home/phd-leonardo-sitl/Desktop/PhdLeo/AutoClutch/df_surgeons/df_VL2.csv
# /home/phd-leonardo-sitl/Desktop/PhdLeo/AutoClutch/bag_folder/dvrk_pedals_VL2.bag
# processing file:  /home/phd-leonardo-sitl/Desktop/PhdLeo/AutoClutch/bag_folder/dvrk_kinematics_MDP1.bag
# [INFO]  Data folder /home/phd-leonardo-sitl/Desktop/PhdLeo/AutoClutch/bag_folder/dvrk_kinematics_MDP1 already exists. Not creating.
#                             Topics                           Types  \
# 0    /ECM/custom/local/setpoint_cp  geometry_msgs/TransformStamped
# 1          /ECM/custom/setpoint_cp  geometry_msgs/TransformStamped
# 2                 /ECM/measured_js          sensor_msgs/JointState
# 3        /MTML/gripper/measured_js          sensor_msgs/JointState
# 4          /MTML/local/measured_cp  geometry_msgs/TransformStamped
# 5                /MTML/measured_cp  geometry_msgs/TransformStamped
# 6                /MTML/measured_js          sensor_msgs/JointState
# 7        /MTMR/gripper/measured_js          sensor_msgs/JointState
# 8          /MTMR/local/measured_cp  geometry_msgs/TransformStamped
# 9                /MTMR/measured_cp  geometry_msgs/TransformStamped
# 10               /MTMR/measured_js          sensor_msgs/JointState
# 11  /PSM1/custom/local/setpoint_cp  geometry_msgs/TransformStamped
# 12        /PSM1/custom/setpoint_cp  geometry_msgs/TransformStamped
# 13           /PSM1/jaw/measured_js          sensor_msgs/JointState
# 14               /PSM1/measured_js          sensor_msgs/JointState
# 15  /PSM2/custom/local/setpoint_cp  geometry_msgs/TransformStamped
# 16        /PSM2/custom/setpoint_cp  geometry_msgs/TransformStamped
# 17           /PSM2/jaw/measured_js          sensor_msgs/JointState
# 18               /PSM2/measured_js          sensor_msgs/JointState
#
#     Message Count   Frequency
# 0           20102   99.546779
# 1           20102   99.546779
# 2           20102  101.016450
# 3           20102  101.009151
# 4           20102   99.788352
# 5           20102   99.788352
# 6           20102  101.009151
# 7           20102  101.009151
# 8           20102   99.797849
# 9           20102   99.793100
# 10          20102  101.011584
# 11          20102   99.546779
# 12          20102   99.546779
# 13          20102   99.781230
# 14          20102  101.001854
# 15          20102   99.546779
# 16          20102   99.546779
# 17          20102   99.788352
# 18          20102  100.999422
# /home/phd-leonardo-sitl/Desktop/PhdLeo/AutoClutch/bag_folder/dvrk_kinematics_MDP1/ECM-custom-local-setpoint_cp.csv
# renaming columns
# psm1
# psm2
# mtml
# mtmr
# ecm
# processing pedals:  /home/phd-leonardo-sitl/Desktop/PhdLeo/AutoClutch/bag_folder/dvrk_pedals_MDP1.bag
# [INFO]  Data folder /home/phd-leonardo-sitl/Desktop/PhdLeo/AutoClutch/bag_folder/dvrk_pedals_MDP1 already exists. Not creating.
#               Topics                  Types  Message Count   Frequency
# 0    /pedals/bipolar  sitl_dvrk/BoolStamped          20081   83.334406
# 1     /pedals/camera  sitl_dvrk/BoolStamped          20081  100.016787
# 2     /pedals/clutch  sitl_dvrk/BoolStamped          20081  100.016787
# 3  /pedals/monopolar  sitl_dvrk/BoolStamped          20081   83.334406
# No data on the topic:/pedals/read/monopolar
# Time
# PSM1_transform.translation.x
# PSM1_transform.translation.y
# PSM1_transform.translation.z
# PSM1_transform.rotation.x
# PSM1_transform.rotation.y
# PSM1_transform.rotation.z
# PSM1_transform.rotation.w
# PSM2_transform.translation.x
# PSM2_transform.translation.y
# PSM2_transform.translation.z
# PSM2_transform.rotation.x
# PSM2_transform.rotation.y
# PSM2_transform.rotation.z
# PSM2_transform.rotation.w
# ECM_transform.translation.x
# ECM_transform.translation.y
# ECM_transform.translation.z
# ECM_transform.rotation.x
# ECM_transform.rotation.y
# ECM_transform.rotation.z
# ECM_transform.rotation.w
# MTML_transform.translation.x
# MTML_transform.translation.y
# MTML_transform.translation.z
# MTML_transform.rotation.x
# MTML_transform.rotation.y
# MTML_transform.rotation.z
# MTML_transform.rotation.w
# MTMR_transform.translation.x
# MTMR_transform.translation.y
# MTMR_transform.translation.z
# MTMR_transform.rotation.x
# MTMR_transform.rotation.y
# MTMR_transform.rotation.z
# MTMR_transform.rotation.w
# data_clutch
# data_camera
# data_monopolar
# dataset created with the name:  /home/phd-leonardo-sitl/Desktop/PhdLeo/AutoClutch/df_surgeons/df_MDP1.csv
# /home/phd-leonardo-sitl/Desktop/PhdLeo/AutoClutch/bag_folder/dvrk_pedals_MDP1.bag
# processing file:  /home/phd-leonardo-sitl/Desktop/PhdLeo/AutoClutch/bag_folder/dvrk_kinematics_MDP3.bag
# [INFO]  Data folder /home/phd-leonardo-sitl/Desktop/PhdLeo/AutoClutch/bag_folder/dvrk_kinematics_MDP3 already exists. Not creating.
#                             Topics                           Types  \
# 0    /ECM/custom/local/setpoint_cp  geometry_msgs/TransformStamped
# 1          /ECM/custom/setpoint_cp  geometry_msgs/TransformStamped
# 2                 /ECM/measured_js          sensor_msgs/JointState
# 3        /MTML/gripper/measured_js          sensor_msgs/JointState
# 4          /MTML/local/measured_cp  geometry_msgs/TransformStamped
# 5                /MTML/measured_cp  geometry_msgs/TransformStamped
# 6                /MTML/measured_js          sensor_msgs/JointState
# 7        /MTMR/gripper/measured_js          sensor_msgs/JointState
# 8          /MTMR/local/measured_cp  geometry_msgs/TransformStamped
# 9                /MTMR/measured_cp  geometry_msgs/TransformStamped
# 10               /MTMR/measured_js          sensor_msgs/JointState
# 11  /PSM1/custom/local/setpoint_cp  geometry_msgs/TransformStamped
# 12        /PSM1/custom/setpoint_cp  geometry_msgs/TransformStamped
# 13           /PSM1/jaw/measured_js          sensor_msgs/JointState
# 14               /PSM1/measured_js          sensor_msgs/JointState
# 15  /PSM2/custom/local/setpoint_cp  geometry_msgs/TransformStamped
# 16        /PSM2/custom/setpoint_cp  geometry_msgs/TransformStamped
# 17           /PSM2/jaw/measured_js          sensor_msgs/JointState
# 18               /PSM2/measured_js          sensor_msgs/JointState
#
#     Message Count   Frequency
# 0           83806   99.530244
# 1           83806   99.530244
# 2           83806  101.009151
# 3           83806  100.996990
# 4           83806  101.424385
# 5           83806  101.426837
# 6           83806  100.996990
# 7           83806  100.996990
# 8           83806  101.414575
# 9           83806  101.412123
# 10          83806  100.996990
# 11          83806   99.530244
# 12          83806   99.530244
# 13          83806  101.414575
# 14          83806  100.987263
# 15          83806   99.530244
# 16          83806   99.530244
# 17          83806  101.409671
# 18          83806  100.989695
# /home/phd-leonardo-sitl/Desktop/PhdLeo/AutoClutch/bag_folder/dvrk_kinematics_MDP3/ECM-custom-local-setpoint_cp.csv
# renaming columns
# psm1
# psm2
# mtml
# mtmr
# ecm
# processing pedals:  /home/phd-leonardo-sitl/Desktop/PhdLeo/AutoClutch/bag_folder/dvrk_pedals_MDP3.bag
# [INFO]  Data folder /home/phd-leonardo-sitl/Desktop/PhdLeo/AutoClutch/bag_folder/dvrk_pedals_MDP3 already exists. Not creating.
#               Topics                  Types  Message Count   Frequency
# 0    /pedals/bipolar  sitl_dvrk/BoolStamped          19959   83.334406
# 1     /pedals/camera  sitl_dvrk/BoolStamped          19959  100.007248
# 2     /pedals/clutch  sitl_dvrk/BoolStamped          19959  100.007248
# 3  /pedals/monopolar  sitl_dvrk/BoolStamped          19959   83.334406
# No data on the topic:/pedals/read/monopolar
# Time
# PSM1_transform.translation.x
# PSM1_transform.translation.y
# PSM1_transform.translation.z
# PSM1_transform.rotation.x
# PSM1_transform.rotation.y
# PSM1_transform.rotation.z
# PSM1_transform.rotation.w
# PSM2_transform.translation.x
# PSM2_transform.translation.y
# PSM2_transform.translation.z
# PSM2_transform.rotation.x
# PSM2_transform.rotation.y
# PSM2_transform.rotation.z
# PSM2_transform.rotation.w
# ECM_transform.translation.x
# ECM_transform.translation.y
# ECM_transform.translation.z
# ECM_transform.rotation.x
# ECM_transform.rotation.y
# ECM_transform.rotation.z
# ECM_transform.rotation.w
# MTML_transform.translation.x
# MTML_transform.translation.y
# MTML_transform.translation.z
# MTML_transform.rotation.x
# MTML_transform.rotation.y
# MTML_transform.rotation.z
# MTML_transform.rotation.w
# MTMR_transform.translation.x
# MTMR_transform.translation.y
# MTMR_transform.translation.z
# MTMR_transform.rotation.x
# MTMR_transform.rotation.y
# MTMR_transform.rotation.z
# MTMR_transform.rotation.w
# data_clutch
# data_camera
# data_monopolar
# dataset created with the name:  /home/phd-leonardo-sitl/Desktop/PhdLeo/AutoClutch/df_surgeons/df_MDP3.csv
# /home/phd-leonardo-sitl/Desktop/PhdLeo/AutoClutch/bag_folder/dvrk_pedals_MDP3.bag
# processing file:  /home/phd-leonardo-sitl/Desktop/PhdLeo/AutoClutch/bag_folder/dvrk_kinematics_LA2.bag
# [INFO]  Data folder /home/phd-leonardo-sitl/Desktop/PhdLeo/AutoClutch/bag_folder/dvrk_kinematics_LA2 already exists. Not creating.
#                             Topics                           Types  \
# 0    /ECM/custom/local/setpoint_cp  geometry_msgs/TransformStamped
# 1          /ECM/custom/setpoint_cp  geometry_msgs/TransformStamped
# 2                 /ECM/measured_js          sensor_msgs/JointState
# 3        /MTML/gripper/measured_js          sensor_msgs/JointState
# 4          /MTML/local/measured_cp  geometry_msgs/TransformStamped
# 5                /MTML/measured_cp  geometry_msgs/TransformStamped
# 6                /MTML/measured_js          sensor_msgs/JointState
# 7        /MTMR/gripper/measured_js          sensor_msgs/JointState
# 8          /MTMR/local/measured_cp  geometry_msgs/TransformStamped
# 9                /MTMR/measured_cp  geometry_msgs/TransformStamped
# 10               /MTMR/measured_js          sensor_msgs/JointState
# 11  /PSM1/custom/local/setpoint_cp  geometry_msgs/TransformStamped
# 12        /PSM1/custom/setpoint_cp  geometry_msgs/TransformStamped
# 13           /PSM1/jaw/measured_js          sensor_msgs/JointState
# 14               /PSM1/measured_js          sensor_msgs/JointState
# 15  /PSM2/custom/local/setpoint_cp  geometry_msgs/TransformStamped
# 16        /PSM2/custom/setpoint_cp  geometry_msgs/TransformStamped
# 17           /PSM2/jaw/measured_js          sensor_msgs/JointState
# 18               /PSM2/measured_js          sensor_msgs/JointState
#
#     Message Count   Frequency
# 0          123577   99.511353
# 1          123577   99.511353
# 2          123577  101.062696
# 3          123577  101.065131
# 4          123577  101.140680
# 5          123577  101.140680
# 6          123577  101.065131
# 7          123577  101.062696
# 8          123577  101.135802
# 9          123577  101.138241
# 10         123577  101.062696
# 11         123577   99.511353
# 12         123577   99.511353
# 13         123577  101.126049
# 14         123577  101.072437
# 15         123577   99.511353
# 16         123577   99.511353
# 17         123577  101.121173
# 18         123577  101.067566
# /home/phd-leonardo-sitl/Desktop/PhdLeo/AutoClutch/bag_folder/dvrk_kinematics_LA2/ECM-custom-local-setpoint_cp.csv
# renaming columns
# psm1
# psm2
# mtml
# mtmr
# ecm
# processing pedals:  /home/phd-leonardo-sitl/Desktop/PhdLeo/AutoClutch/bag_folder/dvrk_pedals_LA2.bag
# [INFO]  Data folder /home/phd-leonardo-sitl/Desktop/PhdLeo/AutoClutch/bag_folder/dvrk_pedals_LA2 already exists. Not creating.
#                    Topics                  Types  Message Count   Frequency
# 0          /pedals/camera  sitl_dvrk/BoolStamped         128930  100.007248
# 1          /pedals/clutch  sitl_dvrk/BoolStamped         128930  100.007248
# 2  /pedals/read/monopolar  sitl_dvrk/BoolStamped         128930  111.110334
# Time
# PSM1_transform.translation.x
# PSM1_transform.translation.y
# PSM1_transform.translation.z
# PSM1_transform.rotation.x
# PSM1_transform.rotation.y
# PSM1_transform.rotation.z
# PSM1_transform.rotation.w
# PSM2_transform.translation.x
# PSM2_transform.translation.y
# PSM2_transform.translation.z
# PSM2_transform.rotation.x
# PSM2_transform.rotation.y
# PSM2_transform.rotation.z
# PSM2_transform.rotation.w
# ECM_transform.translation.x
# ECM_transform.translation.y
# ECM_transform.translation.z
# ECM_transform.rotation.x
# ECM_transform.rotation.y
# ECM_transform.rotation.z
# ECM_transform.rotation.w
# MTML_transform.translation.x
# MTML_transform.translation.y
# MTML_transform.translation.z
# MTML_transform.rotation.x
# MTML_transform.rotation.y
# MTML_transform.rotation.z
# MTML_transform.rotation.w
# MTMR_transform.translation.x
# MTMR_transform.translation.y
# MTMR_transform.translation.z
# MTMR_transform.rotation.x
# MTMR_transform.rotation.y
# MTMR_transform.rotation.z
# MTMR_transform.rotation.w
# data_clutch
# data_camera
# data_monopolar
# dataset created with the name:  /home/phd-leonardo-sitl/Desktop/PhdLeo/AutoClutch/df_surgeons/df_LA2.csv
# /home/phd-leonardo-sitl/Desktop/PhdLeo/AutoClutch/bag_folder/dvrk_pedals_LA2.bag
# processing file:  /home/phd-leonardo-sitl/Desktop/PhdLeo/AutoClutch/bag_folder/dvrk_kinematics_GP2.bag
# [INFO]  Data folder /home/phd-leonardo-sitl/Desktop/PhdLeo/AutoClutch/bag_folder/dvrk_kinematics_GP2 already exists. Not creating.
#                             Topics                           Types  \
# 0    /ECM/custom/local/setpoint_cp  geometry_msgs/TransformStamped
# 1          /ECM/custom/setpoint_cp  geometry_msgs/TransformStamped
# 2                 /ECM/measured_js          sensor_msgs/JointState
# 3        /MTML/gripper/measured_js          sensor_msgs/JointState
# 4          /MTML/local/measured_cp  geometry_msgs/TransformStamped
# 5                /MTML/measured_cp  geometry_msgs/TransformStamped
# 6                /MTML/measured_js          sensor_msgs/JointState
# 7        /MTMR/gripper/measured_js          sensor_msgs/JointState
# 8          /MTMR/local/measured_cp  geometry_msgs/TransformStamped
# 9                /MTMR/measured_cp  geometry_msgs/TransformStamped
# 10               /MTMR/measured_js          sensor_msgs/JointState
# 11  /PSM1/custom/local/setpoint_cp  geometry_msgs/TransformStamped
# 12        /PSM1/custom/setpoint_cp  geometry_msgs/TransformStamped
# 13           /PSM1/jaw/measured_js          sensor_msgs/JointState
# 14               /PSM1/measured_js          sensor_msgs/JointState
# 15  /PSM2/custom/local/setpoint_cp  geometry_msgs/TransformStamped
# 16        /PSM2/custom/setpoint_cp  geometry_msgs/TransformStamped
# 17           /PSM2/jaw/measured_js          sensor_msgs/JointState
# 18               /PSM2/measured_js          sensor_msgs/JointState
#
#     Message Count  Frequency
# 0           27868  99.163156
# 1           27868  99.163156
# 2           27868  99.835856
# 3           27868  99.831104
# 4           27868  99.332244
# 5           27868  99.329892
# 6           27868  99.840609
# 7           27868  99.795475
# 8           27868  99.353421
# 9           27868  99.355774
# 10          27868  99.804973
# 11          27868  99.160811
# 12          27868  99.160811
# 13          27868  99.344008
# 14          27868  99.783604
# 15          27868  99.163156
# 16          27868  99.160811
# 17          27868  99.374606
# 18          27868  99.835856
# /home/phd-leonardo-sitl/Desktop/PhdLeo/AutoClutch/bag_folder/dvrk_kinematics_GP2/ECM-custom-local-setpoint_cp.csv
# renaming columns
# psm1
# psm2
# mtml
# mtmr
# ecm
# processing pedals:  /home/phd-leonardo-sitl/Desktop/PhdLeo/AutoClutch/bag_folder/dvrk_pedals_GP2.bag
# [INFO]  Data folder /home/phd-leonardo-sitl/Desktop/PhdLeo/AutoClutch/bag_folder/dvrk_pedals_GP2 already exists. Not creating.
#               Topics                  Types  Message Count   Frequency
# 0    /pedals/bipolar  sitl_dvrk/BoolStamped          28884   83.334406
# 1     /pedals/camera  sitl_dvrk/BoolStamped          28884  100.007248
# 2     /pedals/clutch  sitl_dvrk/BoolStamped          28884  100.007248
# 3  /pedals/monopolar  sitl_dvrk/BoolStamped          28884   83.334406
# No data on the topic:/pedals/read/monopolar
# Time
# PSM1_transform.translation.x
# PSM1_transform.translation.y
# PSM1_transform.translation.z
# PSM1_transform.rotation.x
# PSM1_transform.rotation.y
# PSM1_transform.rotation.z
# PSM1_transform.rotation.w
# PSM2_transform.translation.x
# PSM2_transform.translation.y
# PSM2_transform.translation.z
# PSM2_transform.rotation.x
# PSM2_transform.rotation.y
# PSM2_transform.rotation.z
# PSM2_transform.rotation.w
# ECM_transform.translation.x
# ECM_transform.translation.y
# ECM_transform.translation.z
# ECM_transform.rotation.x
# ECM_transform.rotation.y
# ECM_transform.rotation.z
# ECM_transform.rotation.w
# MTML_transform.translation.x
# MTML_transform.translation.y
# MTML_transform.translation.z
# MTML_transform.rotation.x
# MTML_transform.rotation.y
# MTML_transform.rotation.z
# MTML_transform.rotation.w
# MTMR_transform.translation.x
# MTMR_transform.translation.y
# MTMR_transform.translation.z
# MTMR_transform.rotation.x
# MTMR_transform.rotation.y
# MTMR_transform.rotation.z
# MTMR_transform.rotation.w
# data_clutch
# data_camera
# data_monopolar
# dataset created with the name:  /home/phd-leonardo-sitl/Desktop/PhdLeo/AutoClutch/df_surgeons/df_GP2.csv
# /home/phd-leonardo-sitl/Desktop/PhdLeo/AutoClutch/bag_folder/dvrk_pedals_GP2.bag
# processing file:  /home/phd-leonardo-sitl/Desktop/PhdLeo/AutoClutch/bag_folder/dvrk_kinematics_LA3.bag
# [INFO]  Data folder /home/phd-leonardo-sitl/Desktop/PhdLeo/AutoClutch/bag_folder/dvrk_kinematics_LA3 already exists. Not creating.
#                             Topics                           Types  \
# 0    /ECM/custom/local/setpoint_cp  geometry_msgs/TransformStamped
# 1          /ECM/custom/setpoint_cp  geometry_msgs/TransformStamped
# 2                 /ECM/measured_js          sensor_msgs/JointState
# 3        /MTML/gripper/measured_js          sensor_msgs/JointState
# 4          /MTML/local/measured_cp  geometry_msgs/TransformStamped
# 5                /MTML/measured_cp  geometry_msgs/TransformStamped
# 6                /MTML/measured_js          sensor_msgs/JointState
# 7        /MTMR/gripper/measured_js          sensor_msgs/JointState
# 8          /MTMR/local/measured_cp  geometry_msgs/TransformStamped
# 9                /MTMR/measured_cp  geometry_msgs/TransformStamped
# 10               /MTMR/measured_js          sensor_msgs/JointState
# 11  /PSM1/custom/local/setpoint_cp  geometry_msgs/TransformStamped
# 12        /PSM1/custom/setpoint_cp  geometry_msgs/TransformStamped
# 13           /PSM1/jaw/measured_js          sensor_msgs/JointState
# 14               /PSM1/measured_js          sensor_msgs/JointState
# 15  /PSM2/custom/local/setpoint_cp  geometry_msgs/TransformStamped
# 16        /PSM2/custom/setpoint_cp  geometry_msgs/TransformStamped
# 17           /PSM2/jaw/measured_js          sensor_msgs/JointState
# 18               /PSM2/measured_js          sensor_msgs/JointState
#
#     Message Count   Frequency
# 0           83092   99.511353
# 1           83092   99.511353
# 2           83092  101.062696
# 3           83092  101.065131
# 4           83092  101.143119
# 5           83092  101.145558
# 6           83092  101.065131
# 7           83092  101.060261
# 8           83092  101.138241
# 9           83092  101.138241
# 10          83092  101.060261
# 11          83092   99.511353
# 12          83092   99.511353
# 13          83092  101.133364
# 14          83092  101.074873
# 15          83092   99.511353
# 16          83092   99.511353
# 17          83092  101.123611
# 18          83092  101.070002
# /home/phd-leonardo-sitl/Desktop/PhdLeo/AutoClutch/bag_folder/dvrk_kinematics_LA3/ECM-custom-local-setpoint_cp.csv
# renaming columns
# psm1
# psm2
# mtml
# mtmr
# ecm
# processing pedals:  /home/phd-leonardo-sitl/Desktop/PhdLeo/AutoClutch/bag_folder/dvrk_pedals_LA3.bag
# [INFO]  Data folder /home/phd-leonardo-sitl/Desktop/PhdLeo/AutoClutch/bag_folder/dvrk_pedals_LA3 already exists. Not creating.
#                    Topics                  Types  Message Count   Frequency
# 0          /pedals/camera  sitl_dvrk/BoolStamped          85389  100.007248
# 1          /pedals/clutch  sitl_dvrk/BoolStamped          85389  100.007248
# 2  /pedals/read/monopolar  sitl_dvrk/BoolStamped          85389  111.110334
# Time
# PSM1_transform.translation.x
# PSM1_transform.translation.y
# PSM1_transform.translation.z
# PSM1_transform.rotation.x
# PSM1_transform.rotation.y
# PSM1_transform.rotation.z
# PSM1_transform.rotation.w
# PSM2_transform.translation.x
# PSM2_transform.translation.y
# PSM2_transform.translation.z
# PSM2_transform.rotation.x
# PSM2_transform.rotation.y
# PSM2_transform.rotation.z
# PSM2_transform.rotation.w
# ECM_transform.translation.x
# ECM_transform.translation.y
# ECM_transform.translation.z
# ECM_transform.rotation.x
# ECM_transform.rotation.y
# ECM_transform.rotation.z
# ECM_transform.rotation.w
# MTML_transform.translation.x
# MTML_transform.translation.y
# MTML_transform.translation.z
# MTML_transform.rotation.x
# MTML_transform.rotation.y
# MTML_transform.rotation.z
# MTML_transform.rotation.w
# MTMR_transform.translation.x
# MTMR_transform.translation.y
# MTMR_transform.translation.z
# MTMR_transform.rotation.x
# MTMR_transform.rotation.y
# MTMR_transform.rotation.z
# MTMR_transform.rotation.w
# data_clutch
# data_camera
# data_monopolar
# dataset created with the name:  /home/phd-leonardo-sitl/Desktop/PhdLeo/AutoClutch/df_surgeons/df_LA3.csv
# /home/phd-leonardo-sitl/Desktop/PhdLeo/AutoClutch/bag_folder/dvrk_pedals_LA3.bag
# processing file:  /home/phd-leonardo-sitl/Desktop/PhdLeo/AutoClutch/bag_folder/dvrk_kinematics_GP1.bag
# [INFO]  Data folder /home/phd-leonardo-sitl/Desktop/PhdLeo/AutoClutch/bag_folder/dvrk_kinematics_GP1 already exists. Not creating.
#                             Topics                           Types  \
# 0    /ECM/custom/local/setpoint_cp  geometry_msgs/TransformStamped
# 1          /ECM/custom/setpoint_cp  geometry_msgs/TransformStamped
# 2                 /ECM/measured_js          sensor_msgs/JointState
# 3        /MTML/gripper/measured_js          sensor_msgs/JointState
# 4          /MTML/local/measured_cp  geometry_msgs/TransformStamped
# 5                /MTML/measured_cp  geometry_msgs/TransformStamped
# 6                /MTML/measured_js          sensor_msgs/JointState
# 7        /MTMR/gripper/measured_js          sensor_msgs/JointState
# 8          /MTMR/local/measured_cp  geometry_msgs/TransformStamped
# 9                /MTMR/measured_cp  geometry_msgs/TransformStamped
# 10               /MTMR/measured_js          sensor_msgs/JointState
# 11  /PSM1/custom/local/setpoint_cp  geometry_msgs/TransformStamped
# 12        /PSM1/custom/setpoint_cp  geometry_msgs/TransformStamped
# 13           /PSM1/jaw/measured_js          sensor_msgs/JointState
# 14               /PSM1/measured_js          sensor_msgs/JointState
# 15  /PSM2/custom/local/setpoint_cp  geometry_msgs/TransformStamped
# 16        /PSM2/custom/setpoint_cp  geometry_msgs/TransformStamped
# 17           /PSM2/jaw/measured_js          sensor_msgs/JointState
# 18               /PSM2/measured_js          sensor_msgs/JointState
#
#     Message Count  Frequency
# 0           81869  99.193643
# 1           81869  99.191297
# 2           81869  99.831104
# 3           81869  99.814474
# 4           81869  99.369897
# 5           81869  99.384025
# 6           81869  99.821600
# 7           81869  99.800224
# 8           81869  99.353421
# 9           81869  99.355774
# 10          81869  99.807348
# 11          81869  99.193643
# 12          81869  99.191297
# 13          81869  99.348714
# 14          81869  99.826352
# 15          81869  99.193643
# 16          81869  99.192470
# 17          81869  99.341655
# 18          81869  99.821600
# /home/phd-leonardo-sitl/Desktop/PhdLeo/AutoClutch/bag_folder/dvrk_kinematics_GP1/ECM-custom-local-setpoint_cp.csv
# renaming columns
# psm1
# psm2
# mtml
# mtmr
# ecm
# processing pedals:  /home/phd-leonardo-sitl/Desktop/PhdLeo/AutoClutch/bag_folder/dvrk_pedals_GP1.bag
# [INFO]  Data folder /home/phd-leonardo-sitl/Desktop/PhdLeo/AutoClutch/bag_folder/dvrk_pedals_GP1 already exists. Not creating.
#               Topics                  Types  Message Count   Frequency
# 0    /pedals/bipolar  sitl_dvrk/BoolStamped          86615   83.334406
# 1     /pedals/camera  sitl_dvrk/BoolStamped          86615  100.007248
# 2     /pedals/clutch  sitl_dvrk/BoolStamped          86615  100.007248
# 3  /pedals/monopolar  sitl_dvrk/BoolStamped          86615   83.334406
# No data on the topic:/pedals/read/monopolar
# Time
# PSM1_transform.translation.x
# PSM1_transform.translation.y
# PSM1_transform.translation.z
# PSM1_transform.rotation.x
# PSM1_transform.rotation.y
# PSM1_transform.rotation.z
# PSM1_transform.rotation.w
# PSM2_transform.translation.x
# PSM2_transform.translation.y
# PSM2_transform.translation.z
# PSM2_transform.rotation.x
# PSM2_transform.rotation.y
# PSM2_transform.rotation.z
# PSM2_transform.rotation.w
# ECM_transform.translation.x
# ECM_transform.translation.y
# ECM_transform.translation.z
# ECM_transform.rotation.x
# ECM_transform.rotation.y
# ECM_transform.rotation.z
# ECM_transform.rotation.w
# MTML_transform.translation.x
# MTML_transform.translation.y
# MTML_transform.translation.z
# MTML_transform.rotation.x
# MTML_transform.rotation.y
# MTML_transform.rotation.z
# MTML_transform.rotation.w
# MTMR_transform.translation.x
# MTMR_transform.translation.y
# MTMR_transform.translation.z
# MTMR_transform.rotation.x
# MTMR_transform.rotation.y
# MTMR_transform.rotation.z
# MTMR_transform.rotation.w
# data_clutch
# data_camera
# data_monopolar
# dataset created with the name:  /home/phd-leonardo-sitl/Desktop/PhdLeo/AutoClutch/df_surgeons/df_GP1.csv
# /home/phd-leonardo-sitl/Desktop/PhdLeo/AutoClutch/bag_folder/dvrk_pedals_GP1.bag
# processing file:  /home/phd-leonardo-sitl/Desktop/PhdLeo/AutoClutch/bag_folder/dvrk_kinematics_AM3.bag
# [INFO]  Data folder /home/phd-leonardo-sitl/Desktop/PhdLeo/AutoClutch/bag_folder/dvrk_kinematics_AM3 already exists. Not creating.
#                             Topics                           Types  \
# 0    /ECM/custom/local/setpoint_cp  geometry_msgs/TransformStamped
# 1          /ECM/custom/setpoint_cp  geometry_msgs/TransformStamped
# 2                 /ECM/measured_js          sensor_msgs/JointState
# 3        /MTML/gripper/measured_js          sensor_msgs/JointState
# 4          /MTML/local/measured_cp  geometry_msgs/TransformStamped
# 5                /MTML/measured_cp  geometry_msgs/TransformStamped
# 6                /MTML/measured_js          sensor_msgs/JointState
# 7        /MTMR/gripper/measured_js          sensor_msgs/JointState
# 8          /MTMR/local/measured_cp  geometry_msgs/TransformStamped
# 9                /MTMR/measured_cp  geometry_msgs/TransformStamped
# 10               /MTMR/measured_js          sensor_msgs/JointState
# 11  /PSM1/custom/local/setpoint_cp  geometry_msgs/TransformStamped
# 12        /PSM1/custom/setpoint_cp  geometry_msgs/TransformStamped
# 13           /PSM1/jaw/measured_js          sensor_msgs/JointState
# 14               /PSM1/measured_js          sensor_msgs/JointState
# 15  /PSM2/custom/local/setpoint_cp  geometry_msgs/TransformStamped
# 16        /PSM2/custom/setpoint_cp  geometry_msgs/TransformStamped
# 17           /PSM2/jaw/measured_js          sensor_msgs/JointState
# 18               /PSM2/measured_js          sensor_msgs/JointState
#
#     Message Count   Frequency
# 0           50696   99.520797
# 1           50696   99.520797
# 2           50696  101.060261
# 3           50696  101.065131
# 4           50696  101.145558
# 5           50696  101.145558
# 6           50696  101.065131
# 7           50696  101.062696
# 8           50696  101.145558
# 9           50696  101.143119
# 10          50696  101.062696
# 11          50696   99.520797
# 12          50696   99.520797
# 13          50696  101.135802
# 14          50696  101.074873
# 15          50696   99.520797
# 16          50696   99.520797
# 17          50696  101.133364
# 18          50696  101.077309
# /home/phd-leonardo-sitl/Desktop/PhdLeo/AutoClutch/bag_folder/dvrk_kinematics_AM3/ECM-custom-local-setpoint_cp.csv
# renaming columns
# psm1
# psm2
# mtml
# mtmr
# ecm
# processing pedals:  /home/phd-leonardo-sitl/Desktop/PhdLeo/AutoClutch/bag_folder/dvrk_pedals_AM3.bag
# [INFO]  Data folder /home/phd-leonardo-sitl/Desktop/PhdLeo/AutoClutch/bag_folder/dvrk_pedals_AM3 already exists. Not creating.
#                    Topics                  Types  Message Count   Frequency
# 0          /pedals/camera  sitl_dvrk/BoolStamped          51291  100.004864
# 1          /pedals/clutch  sitl_dvrk/BoolStamped          51291  100.004864
# 2  /pedals/read/monopolar  sitl_dvrk/BoolStamped          51291  111.110334
# Time
# PSM1_transform.translation.x
# PSM1_transform.translation.y
# PSM1_transform.translation.z
# PSM1_transform.rotation.x
# PSM1_transform.rotation.y
# PSM1_transform.rotation.z
# PSM1_transform.rotation.w
# PSM2_transform.translation.x
# PSM2_transform.translation.y
# PSM2_transform.translation.z
# PSM2_transform.rotation.x
# PSM2_transform.rotation.y
# PSM2_transform.rotation.z
# PSM2_transform.rotation.w
# ECM_transform.translation.x
# ECM_transform.translation.y
# ECM_transform.translation.z
# ECM_transform.rotation.x
# ECM_transform.rotation.y
# ECM_transform.rotation.z
# ECM_transform.rotation.w
# MTML_transform.translation.x
# MTML_transform.translation.y
# MTML_transform.translation.z
# MTML_transform.rotation.x
# MTML_transform.rotation.y
# MTML_transform.rotation.z
# MTML_transform.rotation.w
# MTMR_transform.translation.x
# MTMR_transform.translation.y
# MTMR_transform.translation.z
# MTMR_transform.rotation.x
# MTMR_transform.rotation.y
# MTMR_transform.rotation.z
# MTMR_transform.rotation.w
# data_clutch
# data_camera
# data_monopolar
# dataset created with the name:  /home/phd-leonardo-sitl/Desktop/PhdLeo/AutoClutch/df_surgeons/df_AM3.csv
# /home/phd-leonardo-sitl/Desktop/PhdLeo/AutoClutch/bag_folder/dvrk_pedals_AM3.bag
# processing file:  /home/phd-leonardo-sitl/Desktop/PhdLeo/AutoClutch/bag_folder/dvrk_kinematics_AM2.bag
# [INFO]  Data folder /home/phd-leonardo-sitl/Desktop/PhdLeo/AutoClutch/bag_folder/dvrk_kinematics_AM2 already exists. Not creating.
#                             Topics                           Types  \
# 0    /ECM/custom/local/setpoint_cp  geometry_msgs/TransformStamped
# 1          /ECM/custom/setpoint_cp  geometry_msgs/TransformStamped
# 2                 /ECM/measured_js          sensor_msgs/JointState
# 3        /MTML/gripper/measured_js          sensor_msgs/JointState
# 4          /MTML/local/measured_cp  geometry_msgs/TransformStamped
# 5                /MTML/measured_cp  geometry_msgs/TransformStamped
# 6                /MTML/measured_js          sensor_msgs/JointState
# 7        /MTMR/gripper/measured_js          sensor_msgs/JointState
# 8          /MTMR/local/measured_cp  geometry_msgs/TransformStamped
# 9                /MTMR/measured_cp  geometry_msgs/TransformStamped
# 10               /MTMR/measured_js          sensor_msgs/JointState
# 11  /PSM1/custom/local/setpoint_cp  geometry_msgs/TransformStamped
# 12        /PSM1/custom/setpoint_cp  geometry_msgs/TransformStamped
# 13           /PSM1/jaw/measured_js          sensor_msgs/JointState
# 14               /PSM1/measured_js          sensor_msgs/JointState
# 15  /PSM2/custom/local/setpoint_cp  geometry_msgs/TransformStamped
# 16        /PSM2/custom/setpoint_cp  geometry_msgs/TransformStamped
# 17           /PSM2/jaw/measured_js          sensor_msgs/JointState
# 18               /PSM2/measured_js          sensor_msgs/JointState
#
#     Message Count   Frequency
# 0           79885   99.499549
# 1           79885   99.499549
# 2           79885  101.050522
# 3           79885  101.048087
# 4           79885  101.113859
# 5           79885  101.113859
# 6           79885  101.048087
# 7           79885  101.048087
# 8           79885  101.108984
# 9           79885  101.108984
# 10          79885  101.045653
# 11          79885   99.499549
# 12          79885   99.499549
# 13          79885  101.106547
# 14          79885  101.052956
# 15          79885   99.499549
# 16          79885   99.499549
# 17          79885  101.096799
# 18          79885  101.055391
# /home/phd-leonardo-sitl/Desktop/PhdLeo/AutoClutch/bag_folder/dvrk_kinematics_AM2/ECM-custom-local-setpoint_cp.csv
# renaming columns
# psm1
# psm2
# mtml
# mtmr
# ecm
# processing pedals:  /home/phd-leonardo-sitl/Desktop/PhdLeo/AutoClutch/bag_folder/dvrk_pedals_AM2.bag
# [INFO]  Data folder /home/phd-leonardo-sitl/Desktop/PhdLeo/AutoClutch/bag_folder/dvrk_pedals_AM2 already exists. Not creating.
#                    Topics                  Types  Message Count   Frequency
# 0          /pedals/camera  sitl_dvrk/BoolStamped          73311  100.004864
# 1          /pedals/clutch  sitl_dvrk/BoolStamped          73311  100.004864
# 2  /pedals/read/monopolar  sitl_dvrk/BoolStamped          73311  111.110334
# Time
# PSM1_transform.translation.x
# PSM1_transform.translation.y
# PSM1_transform.translation.z
# PSM1_transform.rotation.x
# PSM1_transform.rotation.y
# PSM1_transform.rotation.z
# PSM1_transform.rotation.w
# PSM2_transform.translation.x
# PSM2_transform.translation.y
# PSM2_transform.translation.z
# PSM2_transform.rotation.x
# PSM2_transform.rotation.y
# PSM2_transform.rotation.z
# PSM2_transform.rotation.w
# ECM_transform.translation.x
# ECM_transform.translation.y
# ECM_transform.translation.z
# ECM_transform.rotation.x
# ECM_transform.rotation.y
# ECM_transform.rotation.z
# ECM_transform.rotation.w
# MTML_transform.translation.x
# MTML_transform.translation.y
# MTML_transform.translation.z
# MTML_transform.rotation.x
# MTML_transform.rotation.y
# MTML_transform.rotation.z
# MTML_transform.rotation.w
# MTMR_transform.translation.x
# MTMR_transform.translation.y
# MTMR_transform.translation.z
# MTMR_transform.rotation.x
# MTMR_transform.rotation.y
# MTMR_transform.rotation.z
# MTMR_transform.rotation.w
# data_clutch
# data_camera
# data_monopolar
# dataset created with the name:  /home/phd-leonardo-sitl/Desktop/PhdLeo/AutoClutch/df_surgeons/df_AM2.csv
# /home/phd-leonardo-sitl/Desktop/PhdLeo/AutoClutch/bag_folder/dvrk_pedals_AM2.bag
# processing file:  /home/phd-leonardo-sitl/Desktop/PhdLeo/AutoClutch/bag_folder/dvrk_kinematics_VL3.bag
# [INFO]  Data folder /home/phd-leonardo-sitl/Desktop/PhdLeo/AutoClutch/bag_folder/dvrk_kinematics_VL3 already exists. Not creating.
#                             Topics                           Types  \
# 0    /ECM/custom/local/setpoint_cp  geometry_msgs/TransformStamped
# 1          /ECM/custom/setpoint_cp  geometry_msgs/TransformStamped
# 2                 /ECM/measured_js          sensor_msgs/JointState
# 3        /MTML/gripper/measured_js          sensor_msgs/JointState
# 4          /MTML/local/measured_cp  geometry_msgs/TransformStamped
# 5                /MTML/measured_cp  geometry_msgs/TransformStamped
# 6                /MTML/measured_js          sensor_msgs/JointState
# 7        /MTMR/gripper/measured_js          sensor_msgs/JointState
# 8          /MTMR/local/measured_cp  geometry_msgs/TransformStamped
# 9                /MTMR/measured_cp  geometry_msgs/TransformStamped
# 10               /MTMR/measured_js          sensor_msgs/JointState
# 11  /PSM1/custom/local/setpoint_cp  geometry_msgs/TransformStamped
# 12        /PSM1/custom/setpoint_cp  geometry_msgs/TransformStamped
# 13           /PSM1/jaw/measured_js          sensor_msgs/JointState
# 14               /PSM1/measured_js          sensor_msgs/JointState
# 15  /PSM2/custom/local/setpoint_cp  geometry_msgs/TransformStamped
# 16        /PSM2/custom/setpoint_cp  geometry_msgs/TransformStamped
# 17           /PSM2/jaw/measured_js          sensor_msgs/JointState
# 18               /PSM2/measured_js          sensor_msgs/JointState
#
#     Message Count   Frequency
# 0           76271   99.457081
# 1           76271   99.457081
# 2           76271  100.759219
# 3           76271  100.751958
# 4           76271  100.698742
# 5           76271  100.698742
# 6           76271  100.754378
# 7           76271  100.756798
# 8           76271  100.699951
# 9           76271  100.701160
# 10          76271  100.756798
# 11          76271   99.457081
# 12          76271   99.457081
# 13          76271  100.701160
# 14          76271  100.732600
# 15          76271   99.457081
# 16          76271   99.457081
# 17          76271  100.693907
# 18          76271  100.735019
# /home/phd-leonardo-sitl/Desktop/PhdLeo/AutoClutch/bag_folder/dvrk_kinematics_VL3/ECM-custom-local-setpoint_cp.csv
# renaming columns
# psm1
# psm2
# mtml
# mtmr
# ecm
# processing pedals:  /home/phd-leonardo-sitl/Desktop/PhdLeo/AutoClutch/bag_folder/dvrk_pedals_VL3.bag
# Time
# PSM1_transform.translation.x
# PSM1_transform.translation.y
# PSM1_transform.translation.z
# PSM1_transform.rotation.x
# PSM1_transform.rotation.y
# PSM1_transform.rotation.z
# PSM1_transform.rotation.w
# dataset created with the name:  /home/phd-leonardo-sitl/Desktop/PhdLeo/AutoClutch/df_surgeons/df_VL3.csv
# /home/phd-leonardo-sitl/Desktop/PhdLeo/AutoClutch/bag_folder/dvrk_pedals_VL3.bag
# processing file:  /home/phd-leonardo-sitl/Desktop/PhdLeo/AutoClutch/bag_folder/dvrk_kinematics_AD1.bag
# [INFO]  Data folder /home/phd-leonardo-sitl/Desktop/PhdLeo/AutoClutch/bag_folder/dvrk_kinematics_AD1 already exists. Not creating.
#                             Topics                           Types  \
# 0    /ECM/custom/local/setpoint_cp  geometry_msgs/TransformStamped
# 1          /ECM/custom/setpoint_cp  geometry_msgs/TransformStamped
# 2                 /ECM/measured_js          sensor_msgs/JointState
# 3        /MTML/gripper/measured_js          sensor_msgs/JointState
# 4          /MTML/local/measured_cp  geometry_msgs/TransformStamped
# 5                /MTML/measured_cp  geometry_msgs/TransformStamped
# 6                /MTML/measured_js          sensor_msgs/JointState
# 7        /MTMR/gripper/measured_js          sensor_msgs/JointState
# 8          /MTMR/local/measured_cp  geometry_msgs/TransformStamped
# 9                /MTMR/measured_cp  geometry_msgs/TransformStamped
# 10               /MTMR/measured_js          sensor_msgs/JointState
# 11  /PSM1/custom/local/setpoint_cp  geometry_msgs/TransformStamped
# 12        /PSM1/custom/setpoint_cp  geometry_msgs/TransformStamped
# 13           /PSM1/jaw/measured_js          sensor_msgs/JointState
# 14               /PSM1/measured_js          sensor_msgs/JointState
# 15  /PSM2/custom/local/setpoint_cp  geometry_msgs/TransformStamped
# 16        /PSM2/custom/setpoint_cp  geometry_msgs/TransformStamped
# 17           /PSM2/jaw/measured_js          sensor_msgs/JointState
# 18               /PSM2/measured_js          sensor_msgs/JointState
#
#     Message Count   Frequency
# 0           65631   99.511353
# 1           65631   99.511353
# 2           65631  101.057826
# 3           65631  101.062696
# 4           65631  101.157755
# 5           65631  101.160195
# 6           65631  101.062696
# 7           65631  101.062696
# 8           65631  101.152876
# 9           65631  101.155315
# 10          65631  101.062696
# 11          65631   99.511353
# 12          65631   99.511353
# 13          65631  101.147997
# 14          65631  101.074873
# 15          65631   99.511353
# 16          65631   99.511353
# 17          65631  101.143119
# 18          65631  101.084617
# /home/phd-leonardo-sitl/Desktop/PhdLeo/AutoClutch/bag_folder/dvrk_kinematics_AD1/ECM-custom-local-setpoint_cp.csv
# renaming columns
# psm1
# psm2
# mtml
# mtmr
# ecm
# processing pedals:  /home/phd-leonardo-sitl/Desktop/PhdLeo/AutoClutch/bag_folder/dvrk_pedals_AD1.bag
# [INFO]  Data folder /home/phd-leonardo-sitl/Desktop/PhdLeo/AutoClutch/bag_folder/dvrk_pedals_AD1 already exists. Not creating.
#                    Topics                  Types  Message Count   Frequency
# 0          /pedals/camera  sitl_dvrk/BoolStamped          62189  100.004864
# 1          /pedals/clutch  sitl_dvrk/BoolStamped          62189  100.004864
# 2  /pedals/read/monopolar  sitl_dvrk/BoolStamped          62189  111.110334
# Time
# PSM1_transform.translation.x
# PSM1_transform.translation.y
# PSM1_transform.translation.z
# PSM1_transform.rotation.x
# PSM1_transform.rotation.y
# PSM1_transform.rotation.z
# PSM1_transform.rotation.w
# PSM2_transform.translation.x
# PSM2_transform.translation.y
# PSM2_transform.translation.z
# PSM2_transform.rotation.x
# PSM2_transform.rotation.y
# PSM2_transform.rotation.z
# PSM2_transform.rotation.w
# ECM_transform.translation.x
# ECM_transform.translation.y
# ECM_transform.translation.z
# ECM_transform.rotation.x
# ECM_transform.rotation.y
# ECM_transform.rotation.z
# ECM_transform.rotation.w
# MTML_transform.translation.x
# MTML_transform.translation.y
# MTML_transform.translation.z
# MTML_transform.rotation.x
# MTML_transform.rotation.y
# MTML_transform.rotation.z
# MTML_transform.rotation.w
# MTMR_transform.translation.x
# MTMR_transform.translation.y
# MTMR_transform.translation.z
# MTMR_transform.rotation.x
# MTMR_transform.rotation.y
# MTMR_transform.rotation.z
# MTMR_transform.rotation.w
# data_clutch
# data_camera
# data_monopolar
# dataset created with the name:  /home/phd-leonardo-sitl/Desktop/PhdLeo/AutoClutch/df_surgeons/df_AD1.csv
# /home/phd-leonardo-sitl/Desktop/PhdLeo/AutoClutch/bag_folder/dvrk_pedals_AD1.bag
# processing file:  /home/phd-leonardo-sitl/Desktop/PhdLeo/AutoClutch/bag_folder/dvrk_kinematics_FT3.bag
# [INFO]  Data folder /home/phd-leonardo-sitl/Desktop/PhdLeo/AutoClutch/bag_folder/dvrk_kinematics_FT3 already exists. Not creating.
#                             Topics                           Types  \
# 0    /ECM/custom/local/setpoint_cp  geometry_msgs/TransformStamped
# ...
# 7        /MTMR/gripper/measured_js          sensor_msgs/JointState
# 8          /MTMR/local/measured_cp  geometry_msgs/TransformStamped
# 9                /MTMR/measured_cp  geometry_msgs/TransformStamped
# 10               /MTMR/measured_js          sensor_msgs/JointState
# 11  /PSM1/custom/local/setpoint_cp  geometry_msgs/TransformStamped
# 12        /PSM1/custom/setpoint_cp  geometry_msgs/TransformStamped
# 13           /PSM1/jaw/measured_js          sensor_msgs/JointState
# 14               /PSM1/measured_js          sensor_msgs/JointState
# 15  /PSM2/custom/local/setpoint_cp  geometry_msgs/TransformStamped
# 16        /PSM2/custom/setpoint_cp  geometry_msgs/TransformStamped
# 17           /PSM2/jaw/measured_js          sensor_msgs/JointState
# 18               /PSM2/measured_js          sensor_msgs/JointState
#
#     Message Count   Frequency
# 0           95933   99.506631
# 1           95933   99.506631
# 2           95933  101.057826
# 3           95933  101.062696
# 4           95933  101.123611
# 5           95933  101.123611
# 6           95933  101.062696
# 7           95933  101.065131
# 8           95933  101.118735
# 9           95933  101.118735
# 10          95933  101.065131
# 11          95933   99.506631
# 12          95933   99.506631
# 13          95933  101.111422
# 14          95933  101.074873
# 15          95933   99.506631
# 16          95933   99.506631
# 17          95933  101.104110
# 18          95933  101.082181
# /home/phd-leonardo-sitl/Desktop/PhdLeo/AutoClutch/bag_folder/dvrk_kinematics_AD3/ECM-custom-local-setpoint_cp.csv
# renaming columns
# psm1
# psm2
# mtml
# mtmr
# ecm
# processing pedals:  /home/phd-leonardo-sitl/Desktop/PhdLeo/AutoClutch/bag_folder/dvrk_pedals_AD3.bag
# [INFO]  Data folder /home/phd-leonardo-sitl/Desktop/PhdLeo/AutoClutch/bag_folder/dvrk_pedals_AD3 already exists. Not creating.
#                    Topics                  Types  Message Count   Frequency
# 0          /pedals/camera  sitl_dvrk/BoolStamped          96532  100.004864
# 1          /pedals/clutch  sitl_dvrk/BoolStamped          96532  100.004864
# 2  /pedals/read/monopolar  sitl_dvrk/BoolStamped          96532  111.110334
# Time
# PSM1_transform.translation.x
# PSM1_transform.translation.y
# PSM1_transform.translation.z
# PSM1_transform.rotation.x
# PSM1_transform.rotation.y
# PSM1_transform.rotation.z
# PSM1_transform.rotation.w
# PSM2_transform.translation.x
# PSM2_transform.translation.y
# PSM2_transform.translation.z
# PSM2_transform.rotation.x
# PSM2_transform.rotation.y
# PSM2_transform.rotation.z
# PSM2_transform.rotation.w
# ECM_transform.translation.x
# ECM_transform.translation.y
# ECM_transform.translation.z
# ECM_transform.rotation.x
# ECM_transform.rotation.y
# ECM_transform.rotation.z
# ECM_transform.rotation.w
# MTML_transform.translation.x
# MTML_transform.translation.y
# MTML_transform.translation.z
# MTML_transform.rotation.x
# MTML_transform.rotation.y
# MTML_transform.rotation.z
# MTML_transform.rotation.w
# MTMR_transform.translation.x
# MTMR_transform.translation.y
# MTMR_transform.translation.z
# MTMR_transform.rotation.x
# MTMR_transform.rotation.y
# MTMR_transform.rotation.z
# MTMR_transform.rotation.w
# data_clutch
# data_camera
# data_monopolar
# dataset created with the name:  /home/phd-leonardo-sitl/Desktop/PhdLeo/AutoClutch/df_surgeons/df_AD3.csv
# /home/phd-leonardo-sitl/Desktop/PhdLeo/AutoClutch/bag_folder/dvrk_pedals_AD3.bag
# processing file:  /home/phd-leonardo-sitl/Desktop/PhdLeo/AutoClutch/bag_folder/dvrk_kinematics_FT2.bag
# [INFO]  Data folder /home/phd-leonardo-sitl/Desktop/PhdLeo/AutoClutch/bag_folder/dvrk_kinematics_FT2 already exists. Not creating.
#                             Topics                           Types  \
# 0    /ECM/custom/local/setpoint_cp  geometry_msgs/TransformStamped
# 1          /ECM/custom/setpoint_cp  geometry_msgs/TransformStamped
# 2                 /ECM/measured_js          sensor_msgs/JointState
# 3        /MTML/gripper/measured_js          sensor_msgs/JointState
# 4          /MTML/local/measured_cp  geometry_msgs/TransformStamped
# 5                /MTML/measured_cp  geometry_msgs/TransformStamped
# 6                /MTML/measured_js          sensor_msgs/JointState
# 7        /MTMR/gripper/measured_js          sensor_msgs/JointState
# 8          /MTMR/local/measured_cp  geometry_msgs/TransformStamped
# 9                /MTMR/measured_cp  geometry_msgs/TransformStamped
# 10               /MTMR/measured_js          sensor_msgs/JointState
# 11  /PSM1/custom/local/setpoint_cp  geometry_msgs/TransformStamped
# 12        /PSM1/custom/setpoint_cp  geometry_msgs/TransformStamped
# 13           /PSM1/jaw/measured_js          sensor_msgs/JointState
# 14               /PSM1/measured_js          sensor_msgs/JointState
# 15  /PSM2/custom/local/setpoint_cp  geometry_msgs/TransformStamped
# 16        /PSM2/custom/setpoint_cp  geometry_msgs/TransformStamped
# 17           /PSM2/jaw/measured_js          sensor_msgs/JointState
# 18               /PSM2/measured_js          sensor_msgs/JointState
#
#     Message Count   Frequency
# 0           50706   99.478310
# 1           50706   99.478310
# 2           50706  100.897378
# 3           50706  100.897378
# 4           50706  100.606956
# 5           50706  100.602130
# 6           50706  100.897378
# 7           50706  100.892524
# 8           50706  100.590066
# 9           50706  100.582830
# 10          50706  100.897378
# 11          50706   99.478310
# 12          50706   99.478310
# 13          50706  100.604543
# 14          50706  100.894951
# 15          50706   99.478310
# 16          50706   99.478310
# 17          50706  100.633508
# 18          50706  100.892524
# /home/phd-leonardo-sitl/Desktop/PhdLeo/AutoClutch/bag_folder/dvrk_kinematics_FT2/ECM-custom-local-setpoint_cp.csv
# renaming columns
# psm1
# psm2
# mtml
# mtmr
# ecm
# processing pedals:  /home/phd-leonardo-sitl/Desktop/PhdLeo/AutoClutch/bag_folder/dvrk_pedals_FT2.bag
# [INFO]  Data folder /home/phd-leonardo-sitl/Desktop/PhdLeo/AutoClutch/bag_folder/dvrk_pedals_FT2 already exists. Not creating.
#               Topics                  Types  Message Count   Frequency
# 0    /pedals/bipolar  sitl_dvrk/BoolStamped          69710   83.334406
# 1     /pedals/camera  sitl_dvrk/BoolStamped          69710  100.007248
# 2     /pedals/clutch  sitl_dvrk/BoolStamped          69710  100.004864
# 3  /pedals/monopolar  sitl_dvrk/BoolStamped          69710   83.334406
# No data on the topic:/pedals/read/monopolar
# Time
# PSM1_transform.translation.x
# PSM1_transform.translation.y
# PSM1_transform.translation.z
# PSM1_transform.rotation.x
# PSM1_transform.rotation.y
# PSM1_transform.rotation.z
# PSM1_transform.rotation.w
# PSM2_transform.translation.x
# PSM2_transform.translation.y
# PSM2_transform.translation.z
# PSM2_transform.rotation.x
# PSM2_transform.rotation.y
# PSM2_transform.rotation.z
# PSM2_transform.rotation.w
# ECM_transform.translation.x
# ECM_transform.translation.y
# ECM_transform.translation.z
# ECM_transform.rotation.x
# ECM_transform.rotation.y
# ECM_transform.rotation.z
# ECM_transform.rotation.w
# MTML_transform.translation.x
# MTML_transform.translation.y
# MTML_transform.translation.z
# MTML_transform.rotation.x
# MTML_transform.rotation.y
# MTML_transform.rotation.z
# MTML_transform.rotation.w
# MTMR_transform.translation.x
# MTMR_transform.translation.y
# MTMR_transform.translation.z
# MTMR_transform.rotation.x
# MTMR_transform.rotation.y
# MTMR_transform.rotation.z
# MTMR_transform.rotation.w
# data_clutch
# data_camera
# data_monopolar
# dataset created with the name:  /home/phd-leonardo-sitl/Desktop/PhdLeo/AutoClutch/df_surgeons/df_FT2.csv
# /home/phd-leonardo-sitl/Desktop/PhdLeo/AutoClutch/bag_folder/dvrk_pedals_FT2.bag
# processing file:  /home/phd-leonardo-sitl/Desktop/PhdLeo/AutoClutch/bag_folder/dvrk_kinematics_FT1.bag
# [INFO]  Data folder /home/phd-leonardo-sitl/Desktop/PhdLeo/AutoClutch/bag_folder/dvrk_kinematics_FT1 already exists. Not creating.
#                             Topics                           Types  \
# 0    /ECM/custom/local/setpoint_cp  geometry_msgs/TransformStamped
# 1          /ECM/custom/setpoint_cp  geometry_msgs/TransformStamped
# 2                 /ECM/measured_js          sensor_msgs/JointState
# 3        /MTML/gripper/measured_js          sensor_msgs/JointState
# 4          /MTML/local/measured_cp  geometry_msgs/TransformStamped
# 5                /MTML/measured_cp  geometry_msgs/TransformStamped
# 6                /MTML/measured_js          sensor_msgs/JointState
# 7        /MTMR/gripper/measured_js          sensor_msgs/JointState
# 8          /MTMR/local/measured_cp  geometry_msgs/TransformStamped
# 9                /MTMR/measured_cp  geometry_msgs/TransformStamped
# 10               /MTMR/measured_js          sensor_msgs/JointState
# 11  /PSM1/custom/local/setpoint_cp  geometry_msgs/TransformStamped
# 12        /PSM1/custom/setpoint_cp  geometry_msgs/TransformStamped
# 13           /PSM1/jaw/measured_js          sensor_msgs/JointState
# 14               /PSM1/measured_js          sensor_msgs/JointState
# 15  /PSM2/custom/local/setpoint_cp  geometry_msgs/TransformStamped
# 16        /PSM2/custom/setpoint_cp  geometry_msgs/TransformStamped
# 17           /PSM2/jaw/measured_js          sensor_msgs/JointState
# 18               /PSM2/measured_js          sensor_msgs/JointState
#
#     Message Count   Frequency
# 0          111668   99.527882
# 1          111668   99.527882
# 2          111668  100.829463
# 3          111668  100.822192
# 4          111668   99.636640
# 5          111668   99.631907
# 6          111668  100.827039
# 7          111668  100.831887
# 8          111668   99.634273
# 9          111668   99.629540
# 10         111668  100.834311
# 11         111668   99.527882
# 12         111668   99.527882
# 13         111668   99.643741
# 14         111668  100.824615
# 15         111668   99.527882
# 16         111668   99.527882
# 17         111668   99.636640
# 18         111668  100.827039
# /home/phd-leonardo-sitl/Desktop/PhdLeo/AutoClutch/bag_folder/dvrk_kinematics_FT1/ECM-custom-local-setpoint_cp.csv
# renaming columns
# psm1
# psm2
# mtml
# mtmr
# ecm
# processing pedals:  /home/phd-leonardo-sitl/Desktop/PhdLeo/AutoClutch/bag_folder/dvrk_pedals_FT1.bag
# [INFO]  Data folder /home/phd-leonardo-sitl/Desktop/PhdLeo/AutoClutch/bag_folder/dvrk_pedals_FT1 already exists. Not creating.
#               Topics                  Types  Message Count   Frequency
# 0    /pedals/bipolar  sitl_dvrk/BoolStamped         112693   83.334406
# 1     /pedals/camera  sitl_dvrk/BoolStamped         112693  100.009633
# 2     /pedals/clutch  sitl_dvrk/BoolStamped         112693  100.009633
# 3  /pedals/monopolar  sitl_dvrk/BoolStamped         112693   83.334406
# No data on the topic:/pedals/read/monopolar
# Time
# PSM1_transform.translation.x
# PSM1_transform.translation.y
# PSM1_transform.translation.z
# PSM1_transform.rotation.x
# PSM1_transform.rotation.y
# PSM1_transform.rotation.z
# PSM1_transform.rotation.w
# PSM2_transform.translation.x
# PSM2_transform.translation.y
# PSM2_transform.translation.z
# PSM2_transform.rotation.x
# PSM2_transform.rotation.y
# PSM2_transform.rotation.z
# PSM2_transform.rotation.w
# ECM_transform.translation.x
# ECM_transform.translation.y
# ECM_transform.translation.z
# ECM_transform.rotation.x
# ECM_transform.rotation.y
# ECM_transform.rotation.z
# ECM_transform.rotation.w
# MTML_transform.translation.x
# MTML_transform.translation.y
# MTML_transform.translation.z
# MTML_transform.rotation.x
# MTML_transform.rotation.y
# MTML_transform.rotation.z
# MTML_transform.rotation.w
# MTMR_transform.translation.x
# MTMR_transform.translation.y
# MTMR_transform.translation.z
# MTMR_transform.rotation.x
# MTMR_transform.rotation.y
# MTMR_transform.rotation.z
# MTMR_transform.rotation.w
# data_clutch
# data_camera
# data_monopolar
# dataset created with the name:  /home/phd-leonardo-sitl/Desktop/PhdLeo/AutoClutch/df_surgeons/df_FT1.csv
# /home/phd-leonardo-sitl/Desktop/PhdLeo/AutoClutch/bag_folder/dvrk_pedals_FT1.bag
# processing file:  /home/phd-leonardo-sitl/Desktop/PhdLeo/AutoClutch/bag_folder/dvrk_kinematics_AM1.bag
# [INFO]  Data folder /home/phd-leonardo-sitl/Desktop/PhdLeo/AutoClutch/bag_folder/dvrk_kinematics_AM1 already exists. Not creating.
#                             Topics                           Types  \
# 0    /ECM/custom/local/setpoint_cp  geometry_msgs/TransformStamped
# 1          /ECM/custom/setpoint_cp  geometry_msgs/TransformStamped
# 2                 /ECM/measured_js          sensor_msgs/JointState
# 3        /MTML/gripper/measured_js          sensor_msgs/JointState
# 4          /MTML/local/measured_cp  geometry_msgs/TransformStamped
# 5                /MTML/measured_cp  geometry_msgs/TransformStamped
# 6                /MTML/measured_js          sensor_msgs/JointState
# 7        /MTMR/gripper/measured_js          sensor_msgs/JointState
# 8          /MTMR/local/measured_cp  geometry_msgs/TransformStamped
# 9                /MTMR/measured_cp  geometry_msgs/TransformStamped
# 10               /MTMR/measured_js          sensor_msgs/JointState
# 11  /PSM1/custom/local/setpoint_cp  geometry_msgs/TransformStamped
# 12        /PSM1/custom/setpoint_cp  geometry_msgs/TransformStamped
# 13           /PSM1/jaw/measured_js          sensor_msgs/JointState
# 14               /PSM1/measured_js          sensor_msgs/JointState
# 15  /PSM2/custom/local/setpoint_cp  geometry_msgs/TransformStamped
# 16        /PSM2/custom/setpoint_cp  geometry_msgs/TransformStamped
# 17           /PSM2/jaw/measured_js          sensor_msgs/JointState
# 18               /PSM2/measured_js          sensor_msgs/JointState
#
#     Message Count   Frequency
# 0           29906   99.516075
# 1           29906   99.516075
# 2           29906  101.057826
# 3           29906  101.065131
# 4           29906  101.140680
# 5           29906  101.140680
# 6           29906  101.067566
# 7           29906  101.065131
# 8           29906  101.135802
# 9           29906  101.138241
# 10          29906  101.065131
# 11          29906   99.516075
# 12          29906   99.516075
# 13          29906  101.130925
# 14          29906  101.074873
# 15          29906   99.516075
# 16          29906   99.516075
# 17          29906  101.128487
# 18          29906  101.070002
# /home/phd-leonardo-sitl/Desktop/PhdLeo/AutoClutch/bag_folder/dvrk_kinematics_AM1/ECM-custom-local-setpoint_cp.csv
# renaming columns
# psm1
# psm2
# mtml
# mtmr
# ecm
# processing pedals:  /home/phd-leonardo-sitl/Desktop/PhdLeo/AutoClutch/bag_folder/dvrk_pedals_AM1.bag
# [INFO]  Data folder /home/phd-leonardo-sitl/Desktop/PhdLeo/AutoClutch/bag_folder/dvrk_pedals_AM1 already exists. Not creating.
#                    Topics                  Types  Message Count   Frequency
# 0          /pedals/camera  sitl_dvrk/BoolStamped          19954  100.004864
# 1          /pedals/clutch  sitl_dvrk/BoolStamped          19954  100.004864
# 2  /pedals/read/monopolar  sitl_dvrk/BoolStamped          19954  111.110334
# Time
# PSM1_transform.translation.x
# PSM1_transform.translation.y
# PSM1_transform.translation.z
# PSM1_transform.rotation.x
# PSM1_transform.rotation.y
# PSM1_transform.rotation.z
# PSM1_transform.rotation.w
# PSM2_transform.translation.x
# PSM2_transform.translation.y
# PSM2_transform.translation.z
# PSM2_transform.rotation.x
# PSM2_transform.rotation.y
# PSM2_transform.rotation.z
# PSM2_transform.rotation.w
# ECM_transform.translation.x
# ECM_transform.translation.y
# ECM_transform.translation.z
# ECM_transform.rotation.x
# ECM_transform.rotation.y
# ECM_transform.rotation.z
# ECM_transform.rotation.w
# MTML_transform.translation.x
# MTML_transform.translation.y
# MTML_transform.translation.z
# MTML_transform.rotation.x
# MTML_transform.rotation.y
# MTML_transform.rotation.z
# MTML_transform.rotation.w
# MTMR_transform.translation.x
# MTMR_transform.translation.y
# MTMR_transform.translation.z
# MTMR_transform.rotation.x
# MTMR_transform.rotation.y
# MTMR_transform.rotation.z
# MTMR_transform.rotation.w
# data_clutch
# data_camera
# data_monopolar
# dataset created with the name:  /home/phd-leonardo-sitl/Desktop/PhdLeo/AutoClutch/df_surgeons/df_AM1.csv
# /home/phd-leonardo-sitl/Desktop/PhdLeo/AutoClutch/bag_folder/dvrk_pedals_AM1.bag

# %% [markdown]
# # Merging and Dataset Analysis

# %%
def dataset_analysis(large_dataset):
    print(large_dataset.columns)
    print("First few rows of the dataset:")
    print(large_dataset.head())
    print("Number of rows and columns:", large_dataset.shape)
    print("Memory usage per column:")
    print(large_dataset.memory_usage(deep=True))
    print("Total memory usage of the DataFrame:", large_dataset.memory_usage(deep=True).sum() / (1024 * 1024), "MB")

    print("\nSummary statistics of numerical columns:")
    print(large_dataset.describe())
    print("\nInformation about the dataset:")
    print(large_dataset.info())
    print("\nMissing values in the dataset:")
    print(large_dataset.isnull().sum())
    print("\nUnique values in categorical columns:")

    
    for column in large_dataset.select_dtypes(include='object').columns:
        print(f"{column}: {large_dataset[column].nunique()} unique values")
    
    correlation_matrix = large_dataset.corr()
    print("\nCorrelation matrix:")
    print(correlation_matrix)
    
    
    
    plt.figure(figsize=(10, 8))
    sns.heatmap(correlation_matrix, annot=False, cmap='coolwarm', fmt=".2f")
    plt.title("Correlation Matrix")
    plt.show()

# %%
# Specify the folder path where the datasets are saved
folder_path = ".../df_surgeons"


file_names = glob.glob(folder_path + '/*.csv')

# Print the file names to check if they are being found
print("File Names:", file_names)
dfs = []
for file_name in file_names:
    df = pd.read_csv(file_name, delimiter=',') 
    
    if df.shape[1==39]:
        dfs.append(df)    
        print(df.shape)



# Concatenate
large_dataset = pd.concat(dfs, ignore_index=True)

# Specify the folder path where you want to save the final dataset
large_dataset.to_csv('.../df_surgeons/df_total.csv', index=False)
